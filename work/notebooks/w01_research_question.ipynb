# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/girishpatil935/ML_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
### My lane: Structured Content Archetype Clustering

print("I will use the Structured Content Archetype Clustering lane. My goal is to identify different groups of content pages based on how they perform in search, using measurable metrics such as impressions, clicks, average position, and changes in performance over time. The purpose is not simply to predict a number, but to understand what types of pages exist in the content inventory and what action may be appropriate for each group. For example, some clusters may contain strong-performing pages that should be protected, while others may contain pages that need improvement, monitoring, consolidation, or further investigation. I chose this lane because clustering can turn a large collection of pages into a smaller number of understandable performance archetypes that can support content decisions.")
# Out:
# I will use the Structured Content Archetype Clustering lane. My goal is to identify different groups of content pages based on how they perform in search, using measurable metrics such as impressions, clicks, average position, and changes in performance over time. The purpose is not simply to predict a number, but to understand what types of pages exist in the content inventory and what action may be appropriate for each group. For example, some clusters may contain strong-performing pages that should be protected, while others may contain pages that need improvement, monitoring, consolidation, or further investigation. I chose this lane because clustering can turn a large collection of pages into a smaller number of understandable performance archetypes that can support content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
### Research question

print("What distinct performance archetypes exist among the content pages, and what actions should be considered for pages belonging to each archetype?")

### Decision

print("The main decision is how to prioritize different groups of content pages based on their observed search-performance patterns.")

### Action

print("A content or SEO team could use the resulting clusters to decide which groups of pages should be protected, improved, monitored, consolidated, or investigated further. High-performing clusters may indicate types of pages worth protecting or learning from, while weaker clusters may need optimization or further investigation.")

### Cost of a wrong call

print("A wrong recommendation could lead to useful pages being changed or removed unnecessarily, or cause the team to spend time and resources improving pages that have limited opportunity. Therefore, cluster results should be treated as decision-support rather than automatic instructions to delete or create content.")
# Out:
# What distinct performance archetypes exist among the content pages, and what actions should be considered for pages belonging to each archetype?
# The main decision is how to prioritize different groups of content pages based on their observed search-performance patterns.
# A content or SEO team could use the resulting clusters to decide which groups of pages should be protected, improved, monitored, consolidated, or investigated further. High-performing clusters may indicate types of pages worth protecting or learning from, while weaker clusters may need optimization or further investigation.
# A wrong recommendation could lead to useful pages being changed or removed unnecessarily, or cause the team to spend time and resources improving pages that have limited opportunity. Therefore, cluster results should be treated as decision-support rather than automatic instructions to delete or create content.

# %%
print("question 2 is answered")
# Out:
# question 2 is answered

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
#load starter dataset
url = 'https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)
print("numbers of pages:", len(df))
print("number of columns:", len(df.columns))

#show the column names
print("\nColumns:")
print(df.columns.tolist())
# Out:
# numbers of pages: 30000
# number of columns: 44
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
### What I can claim

print("This project can identify groups of pages that have similar performance characteristics based on structured metrics such as search volume, impressions, clicks, position, competition, and other available measurements.")

print("The clustering can help us understand different types of pages, such as high-performing pages, low-performing pages, pages with high visibility but weak engagement, or other groups that emerge from the data.")

print("These clusters can support decisions such as which types of pages should be protected, improved, monitored, rewritten, merged, or potentially reduced.")

### What I cannot claim

print("The clustering does not prove that one type of page causes better performance than another.")

print("It also does not predict Google's ranking decisions or guarantee that changing a page will increase its traffic or ranking.")

print("The clusters are patterns found in the available data and should be treated as decision-support rather than causal proof.")
# Out:
# This project can identify groups of pages that have similar performance characteristics based on structured metrics such as search volume, impressions, clicks, position, competition, and other available measurements.
# The clustering can help us understand different types of pages, such as high-performing pages, low-performing pages, pages with high visibility but weak engagement, or other groups that emerge from the data.
# These clusters can support decisions such as which types of pages should be protected, improved, monitored, rewritten, merged, or potentially reduced.
# The clustering does not prove that one type of page causes better performance than another.
# It also does not predict Google's ranking decisions or guarantee that changing a page will increase its traffic or ranking.
# The clusters are patterns found in the available data and should be treated as decision-support rather than causal proof.

# %%
print("Section 4 complete: clustering will be used for pattern discovery and decision support, not causal prediction.")
# Out:
# Section 4 complete: clustering will be used for pattern discovery and decision support, not causal prediction.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
